# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import src

# %%
path = '/Users/michaelschaid/GitHub/CNC_pandas_workshop/data/fake_clinical_data.csv'
data_processor = (DataProcessor(path)
                  .get_raw_data()
                  .clean_data()
                  )

data_processor.clean_data
# Out:
#          sex  age  ...        bmi hypertension_category
# 0       male   62  ...  28.140625                normal
# 1       male   68  ...  26.390625                normal
# 2       male   44  ...  30.125000                normal
# 3     female   49  ...  31.109375                normal
# 4     female   67  ...  28.406250                normal
# ...      ...  ...  ...        ...                   ...
# 9995    male   64  ...  31.437500       prehypertension
# 9996    male   67  ...  29.203125                normal
# 9997  female   47  ...  25.656250                normal
# 9998    male   78  ...  31.156250   hypertensive crisis
# 9999    male   82  ...  30.062500                normal
#
# [10000 rows x 17 columns]
